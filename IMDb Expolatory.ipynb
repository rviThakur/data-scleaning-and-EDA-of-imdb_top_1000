# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\ravi\ml\imdb_top_1000.csv")

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.tail()
# Out:
#                                            Poster_Link  \
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 997   From Here to Eternity          1953      Passed  118 min
# 998                Lifeboat          1944         NaN   97 min
# 999            The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# ...

# %%
df.drop('Poster_Link',inplace=True,axis=1)

# %%
df.head(1)
# Out:
#                Series_Title Released_Year Certificate  Runtime  Genre  \
# 0  The Shawshank Redemption          1994           A  142 min  Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
#
#          Director        Star1           Star2       Star3           Star4  \
# 0  Frank Darabont  Tim Robbins  Morgan Freeman  Bob Gunton  William Sadler
#
#    No_of_Votes       Gross
# 0      2343110  28,341,469

# %%
df.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count  1000.000000  843.000000  1.000000e+03
# mean      7.949300   77.971530  2.736929e+05
# std       0.275491   12.376099  3.273727e+05
# min       7.600000   28.000000  2.508800e+04
# 25%       7.700000   70.000000  5.552625e+04
# 50%       7.900000   79.000000  1.385485e+05
# 75%       8.100000   87.000000  3.741612e+05
# max       9.300000  100.000000  2.343110e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Certificate    899 non-null    object
#  3   Runtime        1000 non-null   object
#  4   Genre          1000 non-null   object
#  5   IMDB_Rating    1000 non-null   float64
#  6   Overview       1000 non-null   object
#  7   Meta_score     843 non-null    float64
#  8   Director       1000 non-null   object
#  9   Star1          1000 non-null   object
#  10  Star2          1000 non-null   object
#  11  Star3          1000 non-null   object
#  12  Star4          1000 non-null   object
#  13  No_of_Votes    1000 non-null   int64
#  14  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 117.3+ KB

# %%
 df.isna().sum()
# Out:
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df.shape
# Out:
# (1000, 15)

# %%
df.dropna(axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# Series_Title     0
# Released_Year    0
# Runtime          0
# Genre            0
# IMDB_Rating      0
# Overview         0
# Director         0
# Star1            0
# Star2            0
# Star3            0
# Star4            0
# No_of_Votes      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Runtime', 'Genre', 'IMDB_Rating',
#        'Overview', 'Director', 'Star1', 'Star2', 'Star3', 'Star4',
#        'No_of_Votes'],
#       dtype='object')

# %%
df['Series_Title'].unique()
# Out:
# array(['The Shawshank Redemption', 'The Godfather', 'The Dark Knight',
#        'The Godfather: Part II', '12 Angry Men',
#        'The Lord of the Rings: The Return of the King', 'Pulp Fiction',
#        "Schindler's List", 'Inception', 'Fight Club',
#        'The Lord of the Rings: The Fellowship of the Ring',
#        'Forrest Gump', 'Il buono, il brutto, il cattivo',
#        'The Lord of the Rings: The Two Towers', 'The Matrix',
#        'Goodfellas', 'Star Wars: Episode V - The Empire Strikes Back',
#        "One Flew Over the Cuckoo's Nest", 'Hamilton', 'Gisaengchung',
#        'Soorarai Pottru', 'Interstellar', 'Cidade de Deus',
#        'Sen to Chihiro no kamikakushi', 'Saving Private Ryan',
#        'The Green Mile', 'La vita è bella', 'Se7en',
#        'The Silence of the Lambs', 'Star Wars', 'Seppuku',
#        'Shichinin no samurai', "It's a Wonderful Life", 'Joker',
#        'Whiplash', 'The Intouchables', 'The Prestige', 'The Departed',
# ...

# %%
df['Series_Title'].nunique()
# Out:
# 999

# %%
df.head(1)
# Out:
#                Series_Title Released_Year  Runtime  Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994  142 min  Drama          9.3
#
#                                             Overview        Director  \
# 0  Two imprisoned men bond over a number of years...  Frank Darabont
#
#          Star1           Star2       Star3           Star4  No_of_Votes
# 0  Tim Robbins  Morgan Freeman  Bob Gunton  William Sadler      2343110

# %%
df.Runtime=df.Runtime.apply(lambda x: str(x).replace('min','') if 'min' in str(x) else x)

# %%
df.Runtime[:10]
# Out:
# 0    142
# 1    175
# 2    152
# 3    202
# 4     96
# 5    201
# 6    154
# 7    195
# 8    148
# 9    139
# Name: Runtime, dtype: object

# %%
df.Director.unique()
# Out:
# array(['Frank Darabont', 'Francis Ford Coppola', 'Christopher Nolan',
#        'Sidney Lumet', 'Peter Jackson', 'Quentin Tarantino',
#        'Steven Spielberg', 'David Fincher', 'Robert Zemeckis',
#        'Sergio Leone', 'Lana Wachowski', 'Martin Scorsese',
#        'Irvin Kershner', 'Milos Forman', 'Thomas Kail', 'Bong Joon Ho',
#        'Sudha Kongara', 'Fernando Meirelles', 'Hayao Miyazaki',
#        'Roberto Benigni', 'Jonathan Demme', 'George Lucas',
#        'Masaki Kobayashi', 'Akira Kurosawa', 'Frank Capra',
#        'Todd Phillips', 'Damien Chazelle', 'Olivier Nakache',
#        'Roman Polanski', 'Ridley Scott', 'Tony Kaye', 'Bryan Singer',
#        'Luc Besson', 'Roger Allers', 'James Cameron',
#        'Giuseppe Tornatore', 'Isao Takahata', 'Alfred Hitchcock',
#        'Michael Curtiz', 'Charles Chaplin', 'Nadine Labaki', 'Can Ulkay',
#        'Gayatri', 'Makoto Shinkai', 'Nitesh Tiwari', 'Bob Persichetti',
# ...

# %%
df.Director.nunique()
# Out:
# 548

# %%
df[df['Director']=='Christopher Nolan']
# Out:
#               Series_Title Released_Year Runtime                      Genre  \
# 2          The Dark Knight          2008    152        Action, Crime, Drama
# 8                Inception          2010    148   Action, Adventure, Sci-Fi
# 21            Interstellar          2014    169    Adventure, Drama, Sci-Fi
# 36            The Prestige          2006    130      Drama, Mystery, Sci-Fi
# 63   The Dark Knight Rises          2012    164           Action, Adventure
# 69                 Memento          2000    113           Mystery, Thriller
# 155          Batman Begins          2005    140           Action, Adventure
# 573                Dunkirk          2017    106      Action, Drama, History
#
#      IMDB_Rating                                           Overview  \
# 2            9.0  When the menace known as the Joker wreaks havo...
# 8            8.8  A thief who steals corporate secrets through t...
# 21           8.6  A team of explorers travel through a wormhole ...
# ...

# %%
df[df['Director']=='Christopher Nolan'].value_counts
# Out:
# <bound method DataFrame.value_counts of               Series_Title Released_Year Runtime                      Genre  \
# 2          The Dark Knight          2008    152        Action, Crime, Drama
# 8                Inception          2010    148   Action, Adventure, Sci-Fi
# 21            Interstellar          2014    169    Adventure, Drama, Sci-Fi
# 36            The Prestige          2006    130      Drama, Mystery, Sci-Fi
# 63   The Dark Knight Rises          2012    164           Action, Adventure
# 69                 Memento          2000    113           Mystery, Thriller
# 155          Batman Begins          2005    140           Action, Adventure
# 573                Dunkirk          2017    106      Action, Drama, History
#
#      IMDB_Rating                                           Overview  \
# 2            9.0  When the menace known as the Joker wreaks havo...
# 8            8.8  A thief who steals corporate secrets through t...
# ...

# %%
df[df['Director']=='Quentin Tarantino']
# Out:
#                          Series_Title Released_Year Runtime  \
# 6                        Pulp Fiction          1994    154
# 62                   Django Unchained          2012    165
# 93               Inglourious Basterds          2009    153
# 103                    Reservoir Dogs          1992     99
# 241                 Kill Bill: Vol. 1          2003    111
# 369                 Kill Bill: Vol. 2          2004    137
# 584                 The Hateful Eight          2015    168
# 879  Once Upon a Time... in Hollywood          2019    161
#
#                        Genre  IMDB_Rating  \
# 6               Crime, Drama          8.9
# 62            Drama, Western          8.4
# 93     Adventure, Drama, War          8.3
# 103   Crime, Drama, Thriller          8.3
# 241     Action, Crime, Drama          8.1
# 369  Action, Crime, Thriller          8.0
# 584    Crime, Drama, Mystery          7.8
# 879            Comedy, Drama          7.6
#
# ...

# %%
df.head(1)
# Out:
#                Series_Title Released_Year Runtime  Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994    142   Drama          9.3
#
#                                             Overview        Director  \
# 0  Two imprisoned men bond over a number of years...  Frank Darabont
#
#          Star1           Star2       Star3           Star4  No_of_Votes
# 0  Tim Robbins  Morgan Freeman  Bob Gunton  William Sadler      2343110

# %%
df.groupby('Series_Title').count()['Director']
# Out:
# Series_Title
# (500) Days of Summer           1
# 12 Angry Men                   1
# 12 Years a Slave               1
# 1917                           1
# 2001: A Space Odyssey          1
#                               ..
# Zootopia                       1
# Zulu                           1
# Zwartboek                      1
# À bout de souffle              1
# Ôkami kodomo no Ame to Yuki    1
# Name: Director, Length: 999, dtype: int64

# %%
df[['Series_Title','Director','Genre','IMDB_Rating']].head(10)
# Out:
#                                     Series_Title              Director  \
# 0                       The Shawshank Redemption        Frank Darabont
# 1                                  The Godfather  Francis Ford Coppola
# 2                                The Dark Knight     Christopher Nolan
# 3                         The Godfather: Part II  Francis Ford Coppola
# 4                                   12 Angry Men          Sidney Lumet
# 5  The Lord of the Rings: The Return of the King         Peter Jackson
# 6                                   Pulp Fiction     Quentin Tarantino
# 7                               Schindler's List      Steven Spielberg
# 8                                      Inception     Christopher Nolan
# 9                                     Fight Club         David Fincher
#
#                        Genre  IMDB_Rating
# 0                      Drama          9.3
# 1               Crime, Drama          9.2
# 2       Action, Crime, Drama          9.0
# ...

# %%
df[df['Director']=='Quentin Tarantino'].groupby(['Series_Title','Genre','IMDB_Rating']).sum()
# Out:
#                                                                       No_of_Votes
# Series_Title                     Genre                   IMDB_Rating
# Django Unchained                 Drama, Western          8.4              1357682
# Inglourious Basterds             Adventure, Drama, War   8.3              1267869
# Kill Bill: Vol. 1                Action, Crime, Drama    8.1              1000639
# Kill Bill: Vol. 2                Action, Crime, Thriller 8.0               683900
# Once Upon a Time... in Hollywood Comedy, Drama           7.6               551309
# Pulp Fiction                     Crime, Drama            8.9              1826188
# Reservoir Dogs                   Crime, Drama, Thriller  8.3               918562
# The Hateful Eight                Crime, Drama, Mystery   7.8               517059

# %%
len(df[df['Director']=='Quentin Tarantino'].groupby(['Series_Title','Genre','IMDB_Rating']).sum())
# Out:
# 8

# %%
df[df['Director']=='Christopher Nolan'].groupby(['Series_Title','Genre','IMDB_Rating']).sum()
# Out:
#                                                              No_of_Votes
# Series_Title          Genre                     IMDB_Rating
# Batman Begins         Action, Adventure         8.2              1308302
# Dunkirk               Action, Drama, History    7.8               555092
# Inception             Action, Adventure, Sci-Fi 8.8              2067042
# Interstellar          Adventure, Drama, Sci-Fi  8.6              1512360
# Memento               Mystery, Thriller         8.4              1125712
# The Dark Knight       Action, Crime, Drama      9.0              2303232
# The Dark Knight Rises Action, Adventure         8.4              1516346
# The Prestige          Drama, Mystery, Sci-Fi    8.5              1190259

# %%
len(df[df['Director']=='Christopher Nolan'].groupby(['Series_Title','Genre','IMDB_Rating']).sum())
# Out:
# 8

# %%
df[(df['IMDB_Rating'] >=9)]
# Out:
#                Series_Title Released_Year Runtime                 Genre  \
# 0  The Shawshank Redemption          1994    142                  Drama
# 1             The Godfather          1972    175           Crime, Drama
# 2           The Dark Knight          2008    152   Action, Crime, Drama
# 3    The Godfather: Part II          1974    202           Crime, Drama
# 4              12 Angry Men          1957     96           Crime, Drama
#
#    IMDB_Rating                                           Overview  \
# 0          9.3  Two imprisoned men bond over a number of years...
# 1          9.2  An organized crime dynasty's aging patriarch t...
# 2          9.0  When the menace known as the Joker wreaks havo...
# 3          9.0  The early life and career of Vito Corleone in ...
# 4          9.0  A jury holdout attempts to prevent a miscarria...
#
#                Director           Star1           Star2          Star3  \
# ...

# %%
print(len(df[(df['IMDB_Rating'] >=9)]))
# Out:
# 5

# %%
df[(df['No_of_Votes']>=1000000)]
# Out:
#                                           Series_Title Released_Year Runtime  \
# 0                             The Shawshank Redemption          1994    142
# 1                                        The Godfather          1972    175
# 2                                      The Dark Knight          2008    152
# 3                               The Godfather: Part II          1974    202
# 5        The Lord of the Rings: The Return of the King          2003    201
# 6                                         Pulp Fiction          1994    154
# 7                                     Schindler's List          1993    195
# 8                                            Inception          2010    148
# 9                                           Fight Club          1999    139
# 10   The Lord of the Rings: The Fellowship of the Ring          2001    178
# 11                                        Forrest Gump          1994    142
# ...

# %%
len(df[(df['No_of_Votes']>=1000000)])
# Out:
# 42

# %%
sns.distplot(df.Runtime)
sns.set(rc={'figure.figsize':(25,5)})
# Out:
# C:\Users\ravit\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['No_of_Votes'])
sns.set(rc={'figure.figsize':(25,5)})
# Out:
# C:\Users\ravit\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(df['No_of_Votes'])
# Out:
# C:\Users\ravit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='No_of_Votes'>

# %%
min_n,max_n=df['No_of_Votes'].quantile([0.01,0.99])

# %%
min_n
# Out:
# 26463.93

# %%
max_n
# Out:
# 1517386.209999999

# %%
df[df['No_of_Votes']>max_n]
# Out:
#                                          Series_Title Released_Year Runtime  \
# 0                            The Shawshank Redemption          1994    142
# 1                                       The Godfather          1972    175
# 2                                     The Dark Knight          2008    152
# 5       The Lord of the Rings: The Return of the King          2003    201
# 6                                        Pulp Fiction          1994    154
# 8                                           Inception          2010    148
# 9                                          Fight Club          1999    139
# 10  The Lord of the Rings: The Fellowship of the Ring          2001    178
# 11                                       Forrest Gump          1994    142
# 14                                         The Matrix          1999    136
#
#                         Genre  IMDB_Rating  \
# 0                       Drama          9.3
# 1                Crime, Drama          9.2
# ...

# %%
len(df[df['No_of_Votes']>max_n])
# Out:
# 10

# %%
df[df['No_of_Votes']<min_n]
# Out:
#                           Series_Title Released_Year Runtime  \
# 169                     Dom za vesanje          1988    142
# 264                     Ba wang bie ji          1993    171
# 570                              Raazi          2018    138
# 694                 La planète sauvage          1973     72
# 718  Scarface: The Shame of the Nation          1932     93
# 721                  God's Own Country          2017    104
# 785              The Magdalene Sisters          2002    114
# 814                      Do lok tin si          1995     99
# 863                          Cape Fear          1962    106
# 989                   The Long Goodbye          1973    112
#
#                        Genre  IMDB_Rating  \
# 169     Comedy, Crime, Drama          8.2
# 264    Drama, Music, Romance          8.1
# 570  Action, Drama, Thriller          7.8
# 694        Animation, Sci-Fi          7.8
# 718     Action, Crime, Drama          7.8
# 721           Drama, Romance          7.7
# ...

# %%
len(df[df['No_of_Votes']<min_n])
# Out:
# 10

# %%
sns.boxplot(df['No_of_Votes'])
sns.set(rc={'figure.figsize':(25,5)})
# Out:
# C:\Users\ravit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_new=df[(df['No_of_Votes']>min_n) & (df['No_of_Votes']>max_n)]

# %%
df_new.head()
# Out:
#                                     Series_Title Released_Year Runtime  \
# 0                       The Shawshank Redemption          1994    142
# 1                                  The Godfather          1972    175
# 2                                The Dark Knight          2008    152
# 5  The Lord of the Rings: The Return of the King          2003    201
# 6                                   Pulp Fiction          1994    154
#
#                       Genre  IMDB_Rating  \
# 0                     Drama          9.3
# 1              Crime, Drama          9.2
# 2      Action, Crime, Drama          9.0
# 5  Action, Adventure, Drama          8.9
# 6              Crime, Drama          8.9
#
#                                             Overview              Director  \
# 0  Two imprisoned men bond over a number of years...        Frank Darabont
# 1  An organized crime dynasty's aging patriarch t...  Francis Ford Coppola
# ...

# %%
sns.boxplot(df['IMDB_Rating'])
# Out:
# C:\Users\ravit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='IMDB_Rating'>

# %%
plt.scatter(x='IMDB_Rating',y='Runtime',data=df)
sns.set(rc={'figure.figsize':(25,25)})

# %%
sns.histplot(df.IMDB_Rating,color='red')
sns.set(rc={'figure.figsize':(15,5)})
